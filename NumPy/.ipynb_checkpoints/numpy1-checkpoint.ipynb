# %%
## install numpy
# !pip install numpy

# %%
import time

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
size = 10000000
py_list = list(range(size))
start_time = time.time()
list_square = [x**2 for x in py_list]
end_time = time.time()
print(f"Python List takes = {end_time - start_time} seconds")
# Out:
# Python List takes = 1.3232524394989014 seconds

# %%
import numpy as np
np_arr  = np.array(py_list)
start_time = time.time()
np_arr_square = np_arr**2
end_time = time.time()
print(f"NumPy Array takes = {end_time-start_time} seconds")
# Out:
# NumPy Array takes = 0.04947257041931152 seconds
