# %%
## install numpy
# !pip install numpy

# %%
import time

# %%
import numpy as np

# %%
import sys

# %%
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Validating Performance  -->>
# ## Verifying the Performace of both Python List and Numpy Array by observing the time taken to calculate the squares of their elements

# %%
size = 10000000
py_list = list(range(size))
start_time = time.time()
list_square = [x**2 for x in py_list]
end_time = time.time()
print(f"Python List takes = {end_time - start_time} seconds")
# Out:
# Python List takes = 1.3530938625335693 seconds

# %%
import numpy as np
np_arr  = np.array(py_list)
start_time = time.time()
np_arr_square = np_arr**2
end_time = time.time()
print(f"NumPy Array takes = {end_time-start_time} seconds")
# Out:
# NumPy Array takes = 0.06149125099182129 seconds

# %% [markdown]
# ## VALIDATING MEMORY USAGE -->>
# ## Verifying the Memory Usage of both Python List and Numpy Array by observing the time taken to calculate the squares of their elements

# %%
print(f"Size of Python List is  = {sys.getsizeof(py_list)} bytes")
print(f"Size of Numpy Array is  = {np_arr.nbytes} bytes")
# Out:
# Size of Python List is  = 80000056 bytes
# Size of Numpy Array is  = 80000000 bytes
