# %% [markdown]
# ## Transform Data (For Feature Enginerring)

# %%
## Feature engineering means changing raw data to better form so that machine learing model can better understand and learn it. Improves the perfomance of the model
## Data Transformation means cleaning, converting and reshaping the data
