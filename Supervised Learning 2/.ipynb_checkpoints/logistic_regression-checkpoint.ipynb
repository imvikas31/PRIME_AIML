# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Train a supervised learning model using logistic regression to predict less chance of heart attact and more chance of heart attack

# %% [markdown]
# ### Less Chance Of Heart Attack - O/P -->> 0
# ### More Chance Of Heart Attack - O/P -->> 1

# %%
import pandas as pd 
import  numpy as np
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
