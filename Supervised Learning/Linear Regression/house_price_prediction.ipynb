# %%
# import all libraries
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("HousePricePrediction.csv")

# %%
df.drop(["Id"],axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.drop(["Id"],axis=1,inplace=True)
#       2 df
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
house_data["SalePrice"] = house_data["SalePrice"].fillna(house_data["SalePrice"].mean())
house_data
# Out:
#         Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0        0          60       RL     8450    Inside     1Fam            5
# 1        1          20       RL     9600       FR2     1Fam            8
# 2        2          60       RL    11250    Inside     1Fam            5
# 3        3          70       RL     9550    Corner     1Fam            5
# 4        4          60       RL    14260       FR2     1Fam            5
# ...    ...         ...      ...      ...       ...      ...          ...
# 2914  2914         160       RM     1936    Inside    Twnhs            7
# 2915  2915         160       RM     1894    Inside   TwnhsE            5
# 2916  2916          20       RL    20000    Inside     1Fam            7
# 2917  2917          85       RL    10441    Inside     1Fam            5
# 2918  2918          60       RL     9627    Inside     1Fam            5
#
#       YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  \
# ...

# %%
# Drop records with null values
house_data = house_data.dropna()

house_data.isnull().sum()
house_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea LotConfig BldgType  OverallCond  \
# 0   0          60       RL     8450    Inside     1Fam            5
# 1   1          20       RL     9600       FR2     1Fam            8
# 2   2          60       RL    11250    Inside     1Fam            5
# 3   3          70       RL     9550    Corner     1Fam            5
# 4   4          60       RL    14260       FR2     1Fam            5
#
#    YearBuilt  YearRemodAdd Exterior1st  BsmtFinSF2  TotalBsmtSF  SalePrice
# 0       2003          2003     VinylSd         0.0        856.0   208500.0
# 1       1976          1976     MetalSd         0.0       1262.0   181500.0
# 2       2001          2002     VinylSd         0.0        920.0   223500.0
# 3       1915          1970     Wd Sdng         0.0        756.0   140000.0
# 4       2000          2000     VinylSd         0.0       1145.0   250000.0

# %%
# Data Preprocessing - Encoding (Covered in Supervised ML Part2)
cols = ['MSZoning', 'LotConfig', 'BldgType', 'Exterior1st']
house_data = pd.get_dummies(house_data, columns=cols, drop_first=True)
house_data
# Out:
#         Id  MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  \
# 0        0          60     8450            5       2003          2003
# 1        1          20     9600            8       1976          1976
# 2        2          60    11250            5       2001          2002
# 3        3          70     9550            5       1915          1970
# 4        4          60    14260            5       2000          2000
# ...    ...         ...      ...          ...        ...           ...
# 2914  2914         160     1936            7       1970          1970
# 2915  2915         160     1894            5       1970          1970
# 2916  2916          20    20000            7       1960          1996
# 2917  2917          85    10441            5       1992          1992
# 2918  2918          60     9627            5       1993          1994
#
#       BsmtFinSF2  TotalBsmtSF     SalePrice  MSZoning_FV  ...  \
# 0            0.0        856.0  208500.00000        False  ...
# ...

# %%
# Divide data for input and ouput
d1 = house_data.drop(columns = ["Id","SalePrice"], axis = 1)
d2 = house_data["SalePrice"]
d1
# Out:
#       MSSubClass  LotArea  OverallCond  YearBuilt  YearRemodAdd  BsmtFinSF2  \
# 0             60     8450            5       2003          2003         0.0
# 1             20     9600            8       1976          1976         0.0
# 2             60    11250            5       2001          2002         0.0
# 3             70     9550            5       1915          1970         0.0
# 4             60    14260            5       2000          2000         0.0
# ...          ...      ...          ...        ...           ...         ...
# 2914         160     1936            7       1970          1970         0.0
# 2915         160     1894            5       1970          1970         0.0
# 2916          20    20000            7       1960          1996         0.0
# 2917          85    10441            5       1992          1992         0.0
# 2918          60     9627            5       1993          1994         0.0
#
# ...

# %%
# splittind data for training and testing -->>
d1_train, d1_test, d2_train, d2_test = train_test_split(
    d1, d2, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(d1_train, d2_train)
# Out:
# LinearRegression()

# %%
d2_prediction = model.predict(d1_test)

# %%
d2_prediction
# Out:
# array([ 63305.64566689, 101971.54805633,  71464.70786008, 102954.70782238,
#         98999.54347081, 130288.64472497,  44075.74807229, 122666.56934107,
#         43440.61694413, 111349.28594367,  92591.87347605, 107985.99725977,
#         70690.26109064, 103705.44581154,  85238.18718394,  95864.6296752 ,
#         69498.73180831,  98988.98294786,  44380.04269844,  78369.66843887,
#        109268.68068615,  43918.9935175 ,  39483.78952627, 106164.49911038,
#        117823.44619417,  97851.88326996, 109970.18746515,  52505.65951953,
#        111340.58265052,  69231.15936237, 136770.87635513,  69561.4846277 ,
#        108127.1734626 , 101239.44960161, 120378.30789802, 119050.15633251,
#         83202.54595114,  83684.9635042 ,  63376.43414537,  89408.42537412,
#         45017.16629921,  97339.13780949, 133120.02503081, 103381.37308508,
#         87252.76615457,  83843.34719115, 110416.31793801,  93478.55532032,
# ...

# %%
d2_test.head()
# Out:
# 178     501837.00000
# 678     372500.00000
# 2878    180921.19589
# 2691    180921.19589
# 1898    180921.19589
# Name: SalePrice, dtype: float64
